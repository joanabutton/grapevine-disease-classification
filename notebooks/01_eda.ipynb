# %% [markdown]
# # Dataset Understanding and EDA
#
# ## Project objective
#
# This notebook keeps EDA focused on what the project brief requires: checking whether the selected dataset supports a Deep Learning image-classification proof of concept and identifying modelling risks that affect interpretation.
#
# The dataset paper already documents the broader acquisition context, disease descriptions and known limitations. This notebook should verify the local data, show representative examples and connect the findings to preprocessing, splitting and evaluation decisions.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src import RANDOM_SEED

DATA_DIR = Path("../data/raw")
CLASS_NAMES = [
    "healthy",
    "downy mildew",
    "powdery mildew",
    "Esca complex",
    "erineum mite",
]

np.random.seed(RANDOM_SEED)

# %% [markdown]
# ## Dataset loading
#
# Confirm that the dataset has been downloaded locally and that the class folders match the target labels used by the model.

# %% [markdown]
# ## Dataset structure
#
# Check folder names, file formats and whether raw files remain unchanged in `data/raw/`.

# %% [markdown]
# ## Class distribution
#
# Compare local class counts with the dataset paper and note any imbalance that could affect training or evaluation.

# %% [markdown]
# ## Image dimensions
#
# Verify image dimensions and decide which resolution will be resized into the CNN input shape.

# %% [markdown]
# ## Example images by class
#
# Show a small representative image grid for each class. Focus on variation that affects modelling: lighting, background, orientation, symptom visibility and symptom similarity.

# %% [markdown]
# ## Data quality checks
#
# Check for unreadable files, duplicate-looking filenames, unexpected formats and obvious labelling or folder issues. Keep this section concise.

# %% [markdown]
# ## Train / validation / test split
#
# Define one reproducible split for the whole team. Note any risk from images being unevenly distributed by date, location or cultivar.

# %% [markdown]
# ## Preprocessing summary
#
# Summarise the preprocessing choices that the CNN notebook must use: image size, normalisation, label encoding and any augmentation if later approved.

# %% [markdown]
# ## EDA conclusions
#
# Conclude with the points needed for the final interpretation: whether the dataset is suitable for a CNN proof of concept, what limitations must be considered and how the model output could support human vineyard inspection.
